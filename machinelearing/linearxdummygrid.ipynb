# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

from sklearn.compose import ColumnTransformer
from sklearn.dummy import DummyRegressor
from sklearn.linear_model import ElasticNet, LinearRegression
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import (
    OrdinalEncoder,
    OneHotEncoder,
    PolynomialFeatures,
    PowerTransformer,
    RobustScaler,
    StandardScaler,
    QuantileTransformer,
)

DADOS_LIMPOS = 'dados_clean.parquet'
from auxiliares import dataframe_coeficientes
from graficos import (
    plot_coeficientes,
    plot_comparar_metricas_modelos,
    plot_residuos_estimador,
)
from models import (
    organiza_resultados,
    treinar_e_validar_modelo_regressao,
    grid_search_cv_regressor,
)

# %%
df = pd.read_parquet(DADOS_LIMPOS)

df.head()
# Out:
#     longitude   latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0 -122.230003  37.880001                  41          880             129
# 1 -122.220001  37.860001                  21         7099            1106
# 2 -122.260002  37.840000                  42         2555             665
# 3 -122.260002  37.849998                  50         1120             283
# 4 -122.260002  37.840000                  50         2239             455
#
#    population  households  median_income  median_house_value ocean_proximity  \
# 0         322         126         8.3252              452600        NEAR BAY
# 1        2401        1138         8.3014              358500        NEAR BAY
# 2        1206         595         2.0804              226700        NEAR BAY
# 3         697         264         2.1250              140000        NEAR BAY
# 4         990         419         1.9911              158700        NEAR BAY
#
#    median_income_cat  rooms_per_household  population_per_household  \
# 0                  5             6.984127                  2.555556
# 1                  5             6.238137                  2.109842
# 2                  2             4.294117                  2.026891
# 3                  2             4.242424                  2.640152
# 4                  2             5.343676                  2.362768
#
#    bedrooms_per_room
# 0           0.146591
# 1           0.155797
# 2           0.260274
# 3           0.252679
# 4           0.203216

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17564 entries, 0 to 17563
# Data columns (total 14 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   longitude                 17564 non-null  float32
#  1   latitude                  17564 non-null  float32
#  2   housing_median_age        17564 non-null  int8
#  3   total_rooms               17564 non-null  int16
#  4   total_bedrooms            17564 non-null  int16
#  5   population                17564 non-null  int16
#  6   households                17564 non-null  int16
#  7   median_income             17564 non-null  float32
#  8   median_house_value        17564 non-null  int32
#  9   ocean_proximity           17564 non-null  category
#  10  median_income_cat         17564 non-null  int64
#  11  rooms_per_household       17564 non-null  float32
#  12  population_per_household  17564 non-null  float32
#  13  bedrooms_per_room         17564 non-null  float32
# dtypes: category(1), float32(6), int16(4), int32(1), int64(1), int8(1)
# memory usage: 789.3 KB

# %%
coluna_target = ["median_house_value"]

coluna_one_hot_encoder = ["ocean_proximity"]

coluna_ordinal_encoder = ["median_income_cat"]

# %%
preprocessamento = ColumnTransformer(
    transformers=[
        ("ordinal_encoder", OrdinalEncoder(categories="auto"), coluna_ordinal_encoder),
        ("one_hot", OneHotEncoder(drop="first"), coluna_one_hot_encoder),
    ],
    remainder="passthrough",
)

# %%
X = df.drop(columns=coluna_target)
y = df[coluna_target]

# %%
X.head()
# Out:
#     longitude   latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0 -122.230003  37.880001                  41          880             129
# 1 -122.220001  37.860001                  21         7099            1106
# 2 -122.260002  37.840000                  42         2555             665
# 3 -122.260002  37.849998                  50         1120             283
# 4 -122.260002  37.840000                  50         2239             455
#
#    population  households  median_income ocean_proximity  median_income_cat  \
# 0         322         126         8.3252        NEAR BAY                  5
# 1        2401        1138         8.3014        NEAR BAY                  5
# 2        1206         595         2.0804        NEAR BAY                  2
# 3         697         264         2.1250        NEAR BAY                  2
# 4         990         419         1.9911        NEAR BAY                  2
#
#    rooms_per_household  population_per_household  bedrooms_per_room
# 0             6.984127                  2.555556           0.146591
# 1             6.238137                  2.109842           0.155797
# 2             4.294117                  2.026891           0.260274
# 3             4.242424                  2.640152           0.252679
# 4             5.343676                  2.362768           0.203216

# %%
y.head()
# Out:
#    median_house_value
# 0              452600
# 1              358500
# 2              226700
# 3              140000
# 4              158700

# %%
target_transformer = PowerTransformer()

regressors = {
    "DummyRegressor": {
        "preprocessor": None,
        "regressor": DummyRegressor(strategy="mean"),
        "target_transformer": None,
    },
    "LinearRegression": {
        "preprocessor": preprocessamento,
        "regressor": LinearRegression(),
        "target_transformer": None,
    },
    "LinearRegression_target": {
        "preprocessor": preprocessamento,
        "regressor": LinearRegression(),
        "target_transformer": target_transformer,
    },
}

# %%
resultados = {
    nome_modelo: treinar_e_validar_modelo_regressao(X, y, **regressor)
    for nome_modelo, regressor in regressors.items()
}

df_resultados = organiza_resultados(resultados)

df_resultados
# Out:
#                       model  fit_time score_time   test_r2  \
# 0            DummyRegressor  0.006998      0.007 -0.000081
# 1            DummyRegressor     0.005      0.007 -0.000146
# 2            DummyRegressor     0.004   0.008002 -0.001737
# 3            DummyRegressor  0.006002   0.012999 -0.000101
# 4            DummyRegressor  0.003993   0.010998 -0.000114
# 5          LinearRegression     0.111   0.013164  0.682162
# 6          LinearRegression  0.055649   0.008002   0.66999
# 7          LinearRegression  0.045994   0.009003  0.649247
# 8          LinearRegression  0.062002   0.008998  0.669873
# 9          LinearRegression  0.036001    0.00807  0.669023
# 10  LinearRegression_target     0.069   0.008009  0.684232
# 11  LinearRegression_target  0.049009   0.008001  0.671042
# 12  LinearRegression_target  0.061993      0.007  0.646094
# 13  LinearRegression_target  0.063004   0.007998  0.677544
# 14  LinearRegression_target  0.048998      0.006  0.677014
#
#    test_neg_mean_absolute_error test_neg_root_mean_squared_error time_seconds
# 0                 -77516.042766                    -96239.705692     0.013998
# 1                 -75787.787194                    -95217.629397        0.012
# 2                 -76753.598961                    -96253.253947     0.012003
# 3                 -76837.804811                    -95983.885799     0.019002
# 4                 -76617.245449                    -96182.764729     0.014992
# 5                 -39855.690921                    -54254.958115     0.124164
# 6                 -40272.565406                    -54695.230224     0.063651
# 7                 -42178.059246                    -56955.988686     0.054997
# 8                 -40806.492452                     -55146.31876        0.071
# 9                 -40788.496555                    -55331.351171     0.044072
# 10                -38127.990089                     -54078.01827     0.077009
# 11                -38515.387176                    -54607.941381      0.05701
# 12                -40531.127371                    -57211.351363     0.068994
# 13                -38827.012941                    -54501.880328     0.071002
# 14                -38544.774193                    -54659.330513     0.054998

# %%
df_resultados.groupby("model").mean()
# Out:
#                          fit_time score_time   test_r2  \
# model
# DummyRegressor           0.005199     0.0092 -0.000436
# LinearRegression         0.062129   0.009447  0.668059
# LinearRegression_target  0.058401   0.007402  0.671185
#
#                         test_neg_mean_absolute_error  \
# model
# DummyRegressor                         -76702.495836
# LinearRegression                       -40780.260916
# LinearRegression_target                -38909.258354
#
#                         test_neg_root_mean_squared_error time_seconds
# model
# DummyRegressor                             -95975.447913     0.014399
# LinearRegression                           -55276.769391     0.071577
# LinearRegression_target                    -55011.704371     0.065803

# %%
plot_comparar_metricas_modelos(df_resultados)

# %%
param_grid = {
    "transformer": [None, PowerTransformer(), QuantileTransformer(output_distribution="normal")]
}

# %%
grid_search = grid_search_cv_regressor(
    regressor=LinearRegression(),
    preprocessor=preprocessamento,
    target_transformer=target_transformer,
    param_grid=param_grid,
)

grid_search
# Out:
# GridSearchCV(cv=KFold(n_splits=5, random_state=42, shuffle=True),
#              estimator=TransformedTargetRegressor(regressor=Pipeline(steps=[('preprocessor',
#                                                                              ColumnTransformer(remainder='passthrough',
#                                                                                                transformers=[('ordinal_encoder',
#                                                                                                               OrdinalEncoder(),
#                                                                                                               ['median_income_cat']),
#                                                                                                              ('one_hot',
#                                                                                                               OneHotEncoder(drop='first'),
#                                                                                                               ['ocean_proximity'])])),
#                                                                             ('reg',
#                                                                              LinearRegression())]),
#                                                   transformer=PowerTransformer()),
#              n_jobs=-1,
#              param_grid={'transformer': [None, PowerTransformer(),
#                                          QuantileTransformer(output_distribution='normal')]},
#              refit='neg_root_mean_squared_error',
#              scoring=['r2', 'neg_mean_absolute_error',
#                       'neg_root_mean_squared_error'],
#              verbose=1)

# %%
grid_search.fit(X, y)
# Out:
# Fitting 5 folds for each of 3 candidates, totalling 15 fits
# GridSearchCV(cv=KFold(n_splits=5, random_state=42, shuffle=True),
#              estimator=TransformedTargetRegressor(regressor=Pipeline(steps=[('preprocessor',
#                                                                              ColumnTransformer(remainder='passthrough',
#                                                                                                transformers=[('ordinal_encoder',
#                                                                                                               OrdinalEncoder(),
#                                                                                                               ['median_income_cat']),
#                                                                                                              ('one_hot',
#                                                                                                               OneHotEncoder(drop='first'),
#                                                                                                               ['ocean_proximity'])])),
#                                                                             ('reg',
#                                                                              LinearRegression())]),
#                                                   transformer=PowerTransformer()),
#              n_jobs=-1,
#              param_grid={'transformer': [None, PowerTransformer(),
#                                          QuantileTransformer(output_distribution='normal')]},
#              refit='neg_root_mean_squared_error',
#              scoring=['r2', 'neg_mean_absolute_error',
#                       'neg_root_mean_squared_error'],
#              verbose=1)

# %%
grid_search.best_params_
# Out:
# {'transformer': QuantileTransformer(output_distribution='normal')}

# %%
grid_search.best_score_
# Out:
# np.float64(-54454.30799051621)

# %%
coefs = dataframe_coeficientes(
    grid_search.best_estimator_.regressor_["reg"].coef_,
    grid_search.best_estimator_.regressor_["preprocessor"].get_feature_names_out(),
)

coefs
# Out:
#                                      coeficiente
# one_hot__ocean_proximity_INLAND        -0.455491
# remainder__longitude                   -0.295255
# remainder__latitude                    -0.288636
# remainder__population_per_household    -0.281346
# one_hot__ocean_proximity_NEAR BAY      -0.202464
# one_hot__ocean_proximity_NEAR OCEAN    -0.059397
# remainder__total_bedrooms              -0.000229
# remainder__total_rooms                 -0.000060
# remainder__population                  -0.000035
# remainder__households                   0.000857
# remainder__housing_median_age           0.006662
# ordinal_encoder__median_income_cat      0.033907
# remainder__rooms_per_household          0.117986
# remainder__median_income                0.388229
# remainder__bedrooms_per_room            3.943146

# %%
plot_coeficientes(coefs)

# %%
regressors = {
    "DummyRegressor": {
        "preprocessor": None,
        "regressor": DummyRegressor(strategy="mean"),
        "target_transformer": None,
    },
    "LinearRegression": {
        "preprocessor": preprocessamento,
        "regressor": LinearRegression(),
        "target_transformer": None,
    },
    "LinearRegression_target_power": {
        "preprocessor": preprocessamento,
        "regressor": LinearRegression(),
        "target_transformer": target_transformer,
    },
    "LinearRegression_target_quantile": {
        "preprocessor": grid_search.best_estimator_.regressor_["preprocessor"],
        "regressor": grid_search.best_estimator_.regressor_["reg"],
        "target_transformer": grid_search.best_estimator_.transformer_,
    },
}


resultados = {
    nome_modelo: treinar_e_validar_modelo_regressao(X, y, **regressor)
    for nome_modelo, regressor in regressors.items()
}

df_resultados = organiza_resultados(resultados)

df_resultados
# Out:
#                                model  fit_time score_time   test_r2  \
# 0                     DummyRegressor  0.004136   0.003999 -0.000081
# 1                     DummyRegressor  0.003001   0.004001 -0.000146
# 2                     DummyRegressor  0.002643   0.004003 -0.001737
# 3                     DummyRegressor  0.001998   0.003004 -0.000101
# 4                     DummyRegressor  0.001998   0.003138 -0.000114
# 5                   LinearRegression  0.016242   0.006032  0.682162
# 6                   LinearRegression  0.014166   0.005992   0.66999
# 7                   LinearRegression  0.013164   0.006244  0.649247
# 8                   LinearRegression  0.014204   0.006033  0.669873
# 9                   LinearRegression  0.014246   0.005963  0.669023
# 10     LinearRegression_target_power  0.028456   0.007191  0.684232
# 11     LinearRegression_target_power  0.026242   0.007168  0.671042
# 12     LinearRegression_target_power  0.026259   0.006229  0.646094
# 13     LinearRegression_target_power  0.031284   0.005999  0.677544
# 14     LinearRegression_target_power  0.025452   0.007039  0.677014
# 15  LinearRegression_target_quantile  0.020522   0.006969  0.691943
# 16  LinearRegression_target_quantile   0.02226      0.007  0.678911
# 17  LinearRegression_target_quantile  0.020195   0.007228  0.653454
# 18  LinearRegression_target_quantile  0.019232   0.007037  0.684077
# 19  LinearRegression_target_quantile  0.019374   0.007001  0.682352
#
#    test_neg_mean_absolute_error test_neg_root_mean_squared_error time_seconds
# 0                 -77516.042766                    -96239.705692     0.008135
# 1                 -75787.787194                    -95217.629397     0.007002
# 2                 -76753.598961                    -96253.253947     0.006646
# 3                 -76837.804811                    -95983.885799     0.005002
# 4                 -76617.245449                    -96182.764729     0.005136
# 5                 -39855.690921                    -54254.958115     0.022274
# 6                 -40272.565406                    -54695.230224     0.020158
# 7                 -42178.059246                    -56955.988686     0.019408
# 8                 -40806.492452                     -55146.31876     0.020236
# 9                 -40788.496555                    -55331.351171     0.020209
# 10                -38127.990089                     -54078.01827     0.035648
# 11                -38515.387176                    -54607.941381      0.03341
# 12                -40531.127371                    -57211.351363     0.032487
# 13                -38827.012941                    -54501.880328     0.037283
# 14                -38544.774193                    -54659.330513     0.032491
# 15                -37807.144546                    -53413.638386     0.027491
# 16                -38279.106688                    -53950.854755      0.02926
# 17                -40298.864323                    -56613.377168     0.027423
# 18                -38593.759324                    -53946.920374     0.026269
# 19                -38407.090724                    -54205.736386     0.026375

# %%
df_resultados.groupby("model").mean()
# Out:
#                                   fit_time score_time   test_r2  \
# model
# DummyRegressor                    0.002755   0.003629 -0.000436
# LinearRegression                  0.014404   0.006053  0.668059
# LinearRegression_target_power     0.027539   0.006725  0.671185
# LinearRegression_target_quantile  0.020317   0.007047  0.678148
#
#                                  test_neg_mean_absolute_error  \
# model
# DummyRegressor                                  -76702.495836
# LinearRegression                                -40780.260916
# LinearRegression_target_power                   -38909.258354
# LinearRegression_target_quantile                -38677.193121
#
#                                  test_neg_root_mean_squared_error time_seconds
# model
# DummyRegressor                                      -95975.447913     0.006384
# LinearRegression                                    -55276.769391     0.020457
# LinearRegression_target_power                       -55011.704371     0.034264
# LinearRegression_target_quantile                    -54426.105414     0.027364

# %%
plot_comparar_metricas_modelos(df_resultados)
