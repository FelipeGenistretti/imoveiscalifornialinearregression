# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

from sklearn.compose import ColumnTransformer
from sklearn.dummy import DummyRegressor
from sklearn.linear_model import LinearRegression, Ridge
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import (
    OrdinalEncoder,
    OneHotEncoder,
    PolynomialFeatures,
    PowerTransformer,
    RobustScaler,
    StandardScaler,
    QuantileTransformer,
)

from joblib import dump

DADOS_LIMPOS = 'dados_clean.parquet'
from auxiliares import dataframe_coeficientes
from graficos import (
    plot_coeficientes,
    plot_comparar_metricas_modelos,
    plot_residuos_estimador,
)
from models import (
    organiza_resultados,
    treinar_e_validar_modelo_regressao,
    grid_search_cv_regressor,
)

# %%
df = pd.read_parquet(DADOS_LIMPOS)

df.head()
# Out:
#     longitude   latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0 -122.230003  37.880001                  41          880             129
# 1 -122.220001  37.860001                  21         7099            1106
# 2 -122.260002  37.840000                  42         2555             665
# 3 -122.260002  37.849998                  50         1120             283
# 4 -122.260002  37.840000                  50         2239             455
#
#    population  households  median_income  median_house_value ocean_proximity  \
# 0         322         126         8.3252              452600        NEAR BAY
# 1        2401        1138         8.3014              358500        NEAR BAY
# 2        1206         595         2.0804              226700        NEAR BAY
# 3         697         264         2.1250              140000        NEAR BAY
# 4         990         419         1.9911              158700        NEAR BAY
#
#    median_income_cat  rooms_per_household  population_per_household  \
# 0                  5             6.984127                  2.555556
# 1                  5             6.238137                  2.109842
# 2                  2             4.294117                  2.026891
# 3                  2             4.242424                  2.640152
# 4                  2             5.343676                  2.362768
#
#    bedrooms_per_room
# 0           0.146591
# 1           0.155797
# 2           0.260274
# 3           0.252679
# 4           0.203216

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17564 entries, 0 to 17563
# Data columns (total 14 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   longitude                 17564 non-null  float32
#  1   latitude                  17564 non-null  float32
#  2   housing_median_age        17564 non-null  int8
#  3   total_rooms               17564 non-null  int16
#  4   total_bedrooms            17564 non-null  int16
#  5   population                17564 non-null  int16
#  6   households                17564 non-null  int16
#  7   median_income             17564 non-null  float32
#  8   median_house_value        17564 non-null  int32
#  9   ocean_proximity           17564 non-null  category
#  10  median_income_cat         17564 non-null  int64
#  11  rooms_per_household       17564 non-null  float32
#  12  population_per_household  17564 non-null  float32
#  13  bedrooms_per_room         17564 non-null  float32
# dtypes: category(1), float32(6), int16(4), int32(1), int64(1), int8(1)
# memory usage: 789.3 KB

# %%
coluna_target = ["median_house_value"]

coluna_one_hot_encoder = ["ocean_proximity"]

coluna_ordinal_encoder = ["median_income_cat"]

# %%
colunas_robust_scaler = df.columns.difference(coluna_target + coluna_one_hot_encoder + coluna_ordinal_encoder)

colunas_robust_scaler
# Out:
# Index(['bedrooms_per_room', 'households', 'housing_median_age', 'latitude',
#        'longitude', 'median_income', 'population', 'population_per_household',
#        'rooms_per_household', 'total_bedrooms', 'total_rooms'],
#       dtype='object')

# %%
pipeline_robust = Pipeline(steps=[
    ("robust_scaler", RobustScaler()),
    ("poly", PolynomialFeatures(degree=1, include_bias=False))
])

preprocessamento = ColumnTransformer(
    transformers=[
        ("ordinal_encoder", OrdinalEncoder(categories="auto"), coluna_ordinal_encoder),
        ("one_hot", OneHotEncoder(drop="first"), coluna_one_hot_encoder),
        ("robust_scaler_poly", pipeline_robust, colunas_robust_scaler),
    ],
)

# %%
X = df.drop(columns=coluna_target)
y = df[coluna_target]

# %%
X.head()
# Out:
#     longitude   latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0 -122.230003  37.880001                  41          880             129
# 1 -122.220001  37.860001                  21         7099            1106
# 2 -122.260002  37.840000                  42         2555             665
# 3 -122.260002  37.849998                  50         1120             283
# 4 -122.260002  37.840000                  50         2239             455
#
#    population  households  median_income ocean_proximity  median_income_cat  \
# 0         322         126         8.3252        NEAR BAY                  5
# 1        2401        1138         8.3014        NEAR BAY                  5
# 2        1206         595         2.0804        NEAR BAY                  2
# 3         697         264         2.1250        NEAR BAY                  2
# 4         990         419         1.9911        NEAR BAY                  2
#
#    rooms_per_household  population_per_household  bedrooms_per_room
# 0             6.984127                  2.555556           0.146591
# 1             6.238137                  2.109842           0.155797
# 2             4.294117                  2.026891           0.260274
# 3             4.242424                  2.640152           0.252679
# 4             5.343676                  2.362768           0.203216

# %%
y.head()
# Out:
#    median_house_value
# 0              452600
# 1              358500
# 2              226700
# 3              140000
# 4              158700

# %%
param_grid = {
    "regressor__preprocessor__robust_scaler_poly__poly__degree": [1, 2, 3],
    "regressor__reg__alpha": [1E-2, 5E-2, 0.1, 0.25, 0.5, 1.0, 2.0, 5.0, 10.0, 20.0, 50.0],
}

# %%
grid_search = grid_search_cv_regressor(
    regressor=Ridge(),
    preprocessor=preprocessamento,
    target_transformer=QuantileTransformer(output_distribution="normal"),
    param_grid=param_grid,
)

grid_search
# Out:
# GridSearchCV(cv=KFold(n_splits=5, random_state=42, shuffle=True),
#              estimator=TransformedTargetRegressor(regressor=Pipeline(steps=[('preprocessor',
#                                                                              ColumnTransformer(transformers=[('ordinal_encoder',
#                                                                                                               OrdinalEncoder(),
#                                                                                                               ['median_income_cat']),
#                                                                                                              ('one_hot',
#                                                                                                               OneHotEncoder(drop='first'),
#                                                                                                               ['ocean_proximity']),
#                                                                                                              ('robust_scaler_poly',
#                                                                                                               Pipeline(steps=[('robust_scaler',
#                                                                                                                                Ro...
#                                                                              Ridge())]),
#                                                   transformer=QuantileTransformer(output_distribution='normal')),
#              n_jobs=-1,
#              param_grid={'regressor__preprocessor__robust_scaler_poly__poly__degree': [1,
#                                                                                        2,
#                                                                                        3],
#                          'regressor__reg__alpha': [0.01, 0.05, 0.1, 0.25, 0.5,
#                                                    1.0, 2.0, 5.0, 10.0, 20.0,
#                                                    50.0]},
#              refit='neg_root_mean_squared_error',
#              scoring=['r2', 'neg_mean_absolute_error',
#                       'neg_root_mean_squared_error'],
#              verbose=1)

# %%
grid_search.fit(X, y)
# Out:
# Fitting 5 folds for each of 33 candidates, totalling 165 fits
# GridSearchCV(cv=KFold(n_splits=5, random_state=42, shuffle=True),
#              estimator=TransformedTargetRegressor(regressor=Pipeline(steps=[('preprocessor',
#                                                                              ColumnTransformer(transformers=[('ordinal_encoder',
#                                                                                                               OrdinalEncoder(),
#                                                                                                               ['median_income_cat']),
#                                                                                                              ('one_hot',
#                                                                                                               OneHotEncoder(drop='first'),
#                                                                                                               ['ocean_proximity']),
#                                                                                                              ('robust_scaler_poly',
#                                                                                                               Pipeline(steps=[('robust_scaler',
#                                                                                                                                Ro...
#                                                                              Ridge())]),
#                                                   transformer=QuantileTransformer(output_distribution='normal')),
#              n_jobs=-1,
#              param_grid={'regressor__preprocessor__robust_scaler_poly__poly__degree': [1,
#                                                                                        2,
#                                                                                        3],
#                          'regressor__reg__alpha': [0.01, 0.05, 0.1, 0.25, 0.5,
#                                                    1.0, 2.0, 5.0, 10.0, 20.0,
#                                                    50.0]},
#              refit='neg_root_mean_squared_error',
#              scoring=['r2', 'neg_mean_absolute_error',
#                       'neg_root_mean_squared_error'],
#              verbose=1)

# %%
grid_search.best_params_
# Out:
# {'regressor__preprocessor__robust_scaler_poly__poly__degree': 3,
#  'regressor__reg__alpha': 20.0}

# %%
grid_search.best_score_
# Out:
# np.float64(-50461.44767136757)

# %%
coefs = dataframe_coeficientes(
    grid_search.best_estimator_.regressor_["reg"].coef_,
    grid_search.best_estimator_.regressor_["preprocessor"].get_feature_names_out(),
)

coefs
# Out:
#                                                     coeficiente
# robust_scaler_poly__longitude                         -0.889399
# robust_scaler_poly__latitude                          -0.791656
# one_hot__ocean_proximity_INLAND                       -0.496164
# robust_scaler_poly__population_per_household          -0.331993
# robust_scaler_poly__latitude^2                        -0.289910
# ...                                                         ...
# robust_scaler_poly__housing_median_age longitude^2     0.192582
# robust_scaler_poly__latitude median_income popu...     0.215826
# robust_scaler_poly__housing_median_age median_i...     0.248113
# robust_scaler_poly__bedrooms_per_room                  0.318588
# robust_scaler_poly__median_income                      0.969265
#
# [367 rows x 1 columns]

# %%
plot_coeficientes(coefs)

# %%
coefs[coefs["coeficiente"] == 0]
# Out:
# Empty DataFrame
# Columns: [coeficiente]
# Index: []

# %%
coefs[coefs["coeficiente"].between(-0.2, 0.2) & (coefs["coeficiente"] != 0)]
# Out:
#                                                     coeficiente
# robust_scaler_poly__longitude^3                       -0.199426
# one_hot__ocean_proximity_NEAR BAY                     -0.196152
# robust_scaler_poly__longitude^2 rooms_per_house...    -0.172138
# robust_scaler_poly__housing_median_age median_i...    -0.171309
# robust_scaler_poly__latitude^2 population             -0.170968
# ...                                                         ...
# robust_scaler_poly__bedrooms_per_room housing_m...     0.172200
# robust_scaler_poly__bedrooms_per_room median_in...     0.175499
# robust_scaler_poly__longitude median_income pop...     0.184836
# robust_scaler_poly__latitude^2 longitude               0.189250
# robust_scaler_poly__housing_median_age longitude^2     0.192582
#
# [351 rows x 1 columns]

# %%
plot_coeficientes(coefs[~coefs["coeficiente"].between(-0.2, 0.2)])

# %%
regressors = {
    "DummyRegressor": {
        "preprocessor": None,
        "regressor": DummyRegressor(strategy="mean"),
        "target_transformer": None,
    },
    "LinearRegression": {
        "preprocessor": preprocessamento,
        "regressor": LinearRegression(),
        "target_transformer": None,
    },
    "LinearRegression_target": {
        "preprocessor": preprocessamento,
        "regressor": LinearRegression(),
        "target_transformer": QuantileTransformer(output_distribution="normal"),
    },
    "Ridge_grid_search": {
        "preprocessor": grid_search.best_estimator_.regressor_["preprocessor"],
        "regressor": grid_search.best_estimator_.regressor_["reg"],
        "target_transformer": grid_search.best_estimator_.transformer_,
    },
}


resultados = {
    nome_modelo: treinar_e_validar_modelo_regressao(X, y, **regressor)
    for nome_modelo, regressor in regressors.items()
}

df_resultados = organiza_resultados(resultados)

df_resultados
# Out:
#                       model  fit_time score_time   test_r2  \
# 0            DummyRegressor  0.003971   0.005758 -0.000081
# 1            DummyRegressor  0.003031      0.003 -0.000146
# 2            DummyRegressor  0.002053   0.003963 -0.001737
# 3            DummyRegressor  0.003859   0.003007 -0.000101
# 4            DummyRegressor  0.002004   0.002997 -0.000114
# 5          LinearRegression  0.025839   0.008721  0.682162
# 6          LinearRegression  0.021728   0.007114   0.66999
# 7          LinearRegression  0.023947   0.007241  0.649247
# 8          LinearRegression  0.022155   0.008164  0.669873
# 9          LinearRegression  0.022969   0.007921  0.669023
# 10  LinearRegression_target  0.028756   0.008268  0.692286
# 11  LinearRegression_target  0.027437   0.007825   0.67786
# 12  LinearRegression_target  0.028014   0.007715  0.653746
# 13  LinearRegression_target  0.029675   0.007811   0.68386
# 14  LinearRegression_target   0.02623   0.008994  0.682294
# 15        Ridge_grid_search   0.11027   0.019566  0.744139
# 16        Ridge_grid_search  0.109186   0.020244  0.723844
# 17        Ridge_grid_search  0.109572   0.020437  0.697811
# 18        Ridge_grid_search  0.139863   0.021163  0.725114
# 19        Ridge_grid_search  0.252128   0.020175  0.725707
#
#    test_neg_mean_absolute_error test_neg_root_mean_squared_error time_seconds
# 0                 -77516.042766                    -96239.705692     0.009729
# 1                 -75787.787194                    -95217.629397     0.006032
# 2                 -76753.598961                    -96253.253947     0.006017
# 3                 -76837.804811                    -95983.885799     0.006866
# 4                 -76617.245449                    -96182.764729     0.005002
# 5                 -39855.690996                    -54254.958188      0.03456
# 6                 -40272.565467                    -54695.230283     0.028842
# 7                  -42178.05929                    -56955.988706     0.031188
# 8                 -40806.492497                    -55146.318803     0.030318
# 9                 -40788.496497                     -55331.35106      0.03089
# 10                 -37790.14992                    -53383.889065     0.037024
# 11                -38288.761503                     -54039.13746     0.035262
# 12                -40293.375277                    -56589.465686     0.035729
# 13                -38580.902611                    -53965.470038     0.037486
# 14                -38414.931489                    -54210.681041     0.035223
# 15                -34148.004489                    -48678.631367     0.129836
# 16                -35054.429899                    -50033.751823      0.12943
# 17                  -37073.5331                    -52866.166415     0.130008
# 18                -35286.578989                    -50321.346215     0.161026
# 19                -35295.848022                     -50370.92209     0.272302

# %%
df_resultados.groupby("model").mean()
# Out:
#                          fit_time score_time   test_r2  \
# model
# DummyRegressor           0.002984   0.003745 -0.000436
# LinearRegression         0.023328   0.007832  0.668059
# LinearRegression_target  0.028022   0.008123  0.678009
# Ridge_grid_search        0.144204   0.020317  0.723323
#
#                         test_neg_mean_absolute_error  \
# model
# DummyRegressor                         -76702.495836
# LinearRegression                        -40780.26095
# LinearRegression_target                 -38673.62416
# Ridge_grid_search                        -35371.6789
#
#                         test_neg_root_mean_squared_error time_seconds
# model
# DummyRegressor                             -95975.447913     0.006729
# LinearRegression                           -55276.769408      0.03116
# LinearRegression_target                    -54437.728658     0.036145
# Ridge_grid_search                          -50454.163582      0.16452

# %%
df_resultados.groupby("model").mean().sort_values(by="test_neg_root_mean_squared_error")
# Out:
#                          fit_time score_time   test_r2  \
# model
# DummyRegressor           0.002984   0.003745 -0.000436
# LinearRegression         0.023328   0.007832  0.668059
# LinearRegression_target  0.028022   0.008123  0.678009
# Ridge_grid_search        0.144204   0.020317  0.723323
#
#                         test_neg_mean_absolute_error  \
# model
# DummyRegressor                         -76702.495836
# LinearRegression                        -40780.26095
# LinearRegression_target                 -38673.62416
# Ridge_grid_search                        -35371.6789
#
#                         test_neg_root_mean_squared_error time_seconds
# model
# DummyRegressor                             -95975.447913     0.006729
# LinearRegression                           -55276.769408      0.03116
# LinearRegression_target                    -54437.728658     0.036145
# Ridge_grid_search                          -50454.163582      0.16452

# %%
plot_comparar_metricas_modelos(df_resultados)

# %%
plot_residuos_estimador(grid_search.best_estimator_, X, y, fracao_amostra=0.1, eng_formatter=True)

# %%
modelo_final = dump(grid_search.best_estimator_,'modelo_final.joblib')
